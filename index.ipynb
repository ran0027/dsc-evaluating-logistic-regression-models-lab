# %% [markdown]
# # Evaluating Logistic Regression Models - Lab
#
# ## Introduction
#
# In regression, you are predicting continous values so it makes sense to discuss error as a distance of how far off our estimates were. When classifying a binary variable, however, a model is either correct or incorrect. As a result, we tend to quantify this in terms of how many false positives versus false negatives we come across. In particular, we examine a few different specific measurements when evaluating the performance of a classification algorithm. In this lab, you'll review precision, recall, accuracy, and F1 score in order to evaluate our logistic regression models.
#
#
# ## Objectives
#
# In this lab you will:
#
# - Implement evaluation metrics from scratch using Python
#
#
#
# ## Terminology review
#
# Let's take a moment and review some classification evaluation metrics:
#
#
# $$ \text{Precision} = \frac{\text{Number of True Positives}}{\text{Number of Predicted Positives}} $$
#
# $$ \text{Recall} = \frac{\text{Number of True Positives}}{\text{Number of Actual Total Positives}} $$
#
# $$ \text{Accuracy} = \frac{\text{Number of True Positives + True Negatives}}{\text{Total Observations}} $$
#
# $$ \text{F1 score} = 2 * \frac{\text{Precision * Recall}}{\text{Precision + Recall}} $$

# %% [markdown]
# At times, it may be best to tune a classification algorithm to optimize against precision or recall rather than overall accuracy. For example, imagine the scenario of predicting whether or not a patient is at risk for cancer and should be brought in for additional testing. In cases such as this, we often may want to cast a slightly wider net, and it is preferable to optimize for recall, the number of cancer positive cases, than it is to optimize precision, the percentage of our predicted cancer-risk patients who are indeed positive.

# %% [markdown]
# ## Split the data into training and test sets

# %%
import pandas as pd
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# Split the data first into `X` and `y`, and then into training and test sets. Assign 25% to the test set and set the `random_state` to 0.

# %%
# Import train_test_split
from sklearn.model_selection import train_test_split

# Split data into X and y
y = df['target']
X = df.drop(['target'], axis=1)

# Split the data into a training and a test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %% [markdown]
# ## Build a vanilla logistic regression model
#
# - Import and instantiate `LogisticRegression`
# - Make sure you do not use an intercept term and use the `'liblinear'` solver
# - Fit the model to training data

# %%
# Import LogisticRegression
from sklearn.linear_model import LogisticRegression

# Instantiate LogisticRegression
logreg = LogisticRegression(fit_intercept=False, C=1e12, solver='liblinear')

# Fit to training data
model_log = logreg.fit(X_train, y_train)
model_log
# Out:
# LogisticRegression(C=1000000000000.0, fit_intercept=False, solver='liblinear')

# %%
from sklearn.metrics import confusion_matrix

# %%
import numpy as np

# %%
np.sum(confusion_matrix(y_train, logreg.predict(X_train))[1,:])
# Out:
# 122

# %% [markdown]
# ## Write a function to calculate the precision

# %%
def precision(y, y_hat):
    # how many of our (positive) predictions were correct?
    # build confusion matrix
    cf = confusion_matrix(y, y_hat)
    # get number of true positives
    true_positives = cf[1][1]
    # get number of predicted positives (true + false positives); sum of right col of cf
    predicted_positives = np.sum(cf[:, 1])
    # return percentage; how many predicted positives were correct?
    return true_positives / predicted_positives

# %% [markdown]
# ## Write a function to calculate the recall

# %%
def recall(y, y_hat):
    # how many positives did we correctly identify out of all actual positives?
    # build confusion matrix
    cf = confusion_matrix(y, y_hat)
    # get number of true positives
    true_positives = cf[1][1]
    # get number of actual positives (false negatives + true positives); sum of bottom row
    actual_positives = np.sum(cf[1, :])
    # return percentage; how many actual positives were predicted?
    return true_positives / actual_positives

# %% [markdown]
# ## Write a function to calculate the accuracy

# %%
def accuracy(y, y_hat):
    # how many predictions were correct out of all predictions made?
    # build confusion matrix
    cf = confusion_matrix(y, y_hat)
    # get number of correct predictions
    correct_predictions = cf[0][0] + cf[1][1]
    # get total number of predictions
    n = len(y)
    # return percentage
    return correct_predictions / n

# %% [markdown]
# ## Write a function to calculate the F1 score

# %%
def f1_score(y, y_hat):
    # find the harmonic mean of the precision and recall
    # calculate precision & recall using functions above
    p = precision(y, y_hat)
    r = recall(y, y_hat)
    # return harmonic mean (special case - two variables)
    return 2*(p*r)/(p + r)

# %% [markdown]
# ## Calculate the precision, recall, accuracy, and F1 score of your classifier
#
# Do this for both the training and test sets.

# %%
# Your code here
y_hat_train = model_log.predict(X_train)
print('Training Set:')
print(f'Precison: {precision(y_train, y_hat_train)}')
print(f'Recall: {recall(y_train, y_hat_train)}')
print(f'Accuracy: {accuracy(y_train, y_hat_train)}')
print(f'F1 Score: {f1_score(y_train, y_hat_train)}')
print('\n')
y_hat_test = model_log.predict(X_test)
print('Test Set:')
print(f'Precison: {precision(y_test, y_hat_test)}')
print(f'Recall: {recall(y_test, y_hat_test)}')
print(f'Accuracy: {accuracy(y_test, y_hat_test)}')
print(f'F1 Score: {f1_score(y_test, y_hat_test)}')
# Out:
# Training Set:
# Precison: 0.8396946564885496
# Recall: 0.9016393442622951
# Accuracy: 0.8546255506607929
# F1 Score: 0.8695652173913043
#
#
# Test Set:
# Precison: 0.8125
# Recall: 0.9069767441860465
# Accuracy: 0.8289473684210527
# F1 Score: 0.8571428571428572

# %% [markdown]
# Great job! Now it's time to check your work with `sklearn`.
#
# ## Calculate metrics with `sklearn`
#
# Each of the metrics we calculated above is also available inside the `sklearn.metrics` module.
#
# In the cell below, import the following functions:
#
# * `precision_score`
# * `recall_score`
# * `accuracy_score`
# * `f1_score`
#
# Compare the results of your performance metrics functions above with the `sklearn` functions. Calculate these values for both your train and test set.

# %%
# Your code here
from sklearn.metrics import precision_score, recall_score, accuracy_score,\
f1_score as f1_score2

print('Training Set:')
print(f'Precison: {precision_score(y_train, y_hat_train)}')
print(f'Recall: {recall_score(y_train, y_hat_train)}')
print(f'Accuracy: {accuracy_score(y_train, y_hat_train)}')
print(f'F1 Score: {f1_score2(y_train, y_hat_train)}')
print('\n')

print('Test Set:')
print(f'Precison: {precision_score(y_test, y_hat_test)}')
print(f'Recall: {recall_score(y_test, y_hat_test)}')
print(f'Accuracy: {accuracy_score(y_test, y_hat_test)}')
print(f'F1 Score: {f1_score2(y_test, y_hat_test)}')
# Out:
# Training Set:
# Precison: 0.8396946564885496
# Recall: 0.9016393442622951
# Accuracy: 0.8546255506607929
# F1 Score: 0.8695652173913043
#
#
# Test Set:
# Precison: 0.8125
# Recall: 0.9069767441860465
# Accuracy: 0.8289473684210527
# F1 Score: 0.8571428571428572

# %% [markdown]
# Nicely done! Did the results from `sklearn` match that of your own?

# %% [markdown]
# ## Compare precision, recall, accuracy, and F1 score for train vs test sets

# %% [markdown]
# Calculate and then plot the precision, recall, accuracy, and F1 score for the test and training splits using different training set sizes. What do you notice?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
training_precision = []
testing_precision = []
training_recall = []
testing_recall = []
training_accuracy = []
testing_accuracy = []
training_f1 = []
testing_f1 = []

for i in range(10, 95):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= i/100)
    logreg = LogisticRegression(fit_intercept=False, C=1e20, solver='liblinear')
    model_log = logreg.fit(X_train, y_train)
    y_hat_test = model_log.predict(X_test)
    y_hat_train = model_log.predict(X_train)
    
    training_precision.append(precision_score(y_train, y_hat_train))
    testing_precision.append(precision_score(y_test, y_hat_test))
    training_recall.append(recall_score(y_train, y_hat_train))
    testing_recall.append(recall_score(y_test, y_hat_test))
    training_accuracy.append(accuracy_score(y_train, y_hat_train))
    testing_accuracy.append(accuracy_score(y_test, y_hat_test))
    training_f1.append(f1_score2(y_train, y_hat_train))
    testing_f1.append(f1_score2(y_test, y_hat_test))
    
    # Your code here
fig, ax = plt.subplots(nrows=2, ncols=4, figsize=(15,10))

x = list(range(10, 95))
metrics = [training_precision, testing_precision, training_recall, testing_recall,\
     training_accuracy, testing_accuracy, training_f1, testing_f1]
names = ['training_precision', 'testing_precision', 'training_recall', 'testing_recall',\
     'training_accuracy', 'testing_accuracy', 'training_f1', 'testing_f1']

for n, metric in enumerate(metrics):
    i = n // 4
    j = n % 4
    ax[i][j].plot(x, metric)
    ax[i][j].set_title(names[n])
# Out:
# /Users/user/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %% [markdown]
# Create four scatter plots looking at the train and test precision in the first one, train and test recall in the second one, train and test accuracy in the third one, and train and test F1 score in the fourth one.
#
# We already created the scatter plot for precision:

# %%
# Train and test precision
plt.scatter(list(range(10, 95)), training_precision, label='training_precision')
plt.scatter(list(range(10, 95)), testing_precision, label='testing_precision')
plt.legend()
plt.show()

# %%
# Train and test recall
plt.scatter(list(range(10, 95)), training_recall, label='training_recall')
plt.scatter(list(range(10, 95)), testing_recall, label='testing_recall')
plt.legend()
plt.show()

# %%
# Train and test accuracy
plt.scatter(list(range(10, 95)), training_accuracy, label='training_accuracy')
plt.scatter(list(range(10, 95)), testing_accuracy, label='testing_accuracy')
plt.legend()
plt.show()

# %%
# Train and test F1 score
plt.scatter(list(range(10, 95)), training_f1, label='training_f1_score')
plt.scatter(list(range(10, 95)), testing_f1, label='testing_f1_score')
plt.legend()
plt.show()

# %% [markdown]
# ## Summary
#
# Nice! In this lab, you calculated evaluation metrics for classification algorithms from scratch in Python. Going forward, continue to think about scenarios in which you might prefer to optimize one of these metrics over another.
